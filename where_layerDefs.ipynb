# %% [markdown]
# # `where` are the `layerDefs`?

# %% [markdown]
# Currently there is no official api published on how to further filter the result list returned by `/identify`. There is a working implementation using the query parameter `where`, which is used internally by the viewer, and maybe also externally (to be clarified). This query parameter is however not documented. Upon two requests from clients there have been made attempts to improve and stabilize the possibility to filter. In the current WIP, two query params are used that use exactly the same parsing logic in the background, but different formats in the query, `where` and `layerDefs`. Ideally, we'd just making one of them publicly available (and documented). `layerDefs` offers to extend the current functionality in the future (cross-layer filtering) with keeping the same syntax so it's the preferred solution. You find below an example on how to use `layerDefs` using python.
#
# ## Queryable attributes
# Not all attributes of a model are queryable. The example below shows how to find the ones that can be used to further filter the results found by identify or find:
# ```python
# >>> import requests
# >>> res=requests.get("https://mf-chsdi3.int.bgdi.ch/diemo/rest/services/all/MapServer/ch.swisstopo.amtliches-strassenverzeichnis")
# >>> print(', '.join(['{} ({})'.format(field['name'], field['type']) for field in res.json()['fields']]))
# plzo (VARCHAR), type (VARCHAR), gdenr (INTEGER), gdename (VARCHAR), label (VARCHAR)
# ```
#
# ## layerDefs syntax
# The syntax of the `layerDefs` parameter is a json with the layername as key and the filter expression as value:
# ```
# {"<layername>":"<filter_expression>"}
# ```
# The filter expression can consist of a single expression of the form `<attribute> <operator> <value>` or several of these expressions combined with boolean operators `and` and `or`. `<attribute>` mus be one of the queryable attributes, the type of `<value>` must correspond the the type of the queryable attribute (see above) and `<operator>` can be one of `"<="|">="|"<"|">"|"!="|"="|"ilike"|"not ilike"|"not like"|"like"`.
#
#
# ## Correct encoding
# It's important, that the parameters are correctly serialized and url-encoded, e.g.
# ```python
# >>> import json
# >>> import urllib.parse
# >>> params = {
#         "ch.swisstopo.amtliches-strassenverzeichnis": "plzo = '8302 Kloten'"
#     }
# >>> print(json.dumps(params))
# {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo = '8302 Kloten'"}
# >>> print(urllib.parse.quote(json.dumps(params)))
# %7B%22ch.swisstopo.amtliches-strassenverzeichnis%22%3A%20%22plzo%20%3D%20%278302%20Kloten%27%22%7D
# ```
#
# ## Find and Identify
# The described `layerDefs` syntax is available for both `/find` and `/identify` to subfilter the primary result query. The difference between `/find` and `/identify` is that the primary query is based on a spatial restriction whereas for `/find` the primary query is already defined by an attribute restriction.
#
# ## Examples

# %%
import requests
import pprint
import urllib.parse

####################################
# A list of examples to demonstrate usage
identify_examples = {
    "ch.bazl.luftfahrthindernis": [
        "bgdi_activesince <= '2019-07-30'"
    ],
    "ch.swisstopo.amtliches-strassenverzeichnis": [
        "gdenr << 2704", # should not work
        "gdenr != 2704",
        "plzo ilike '%Olten%' and label ilike '%Studerweg%'",
        "plzo ilike '%Olten%' and label ilike '%Studerwe'", # should return no results
        "plzo ilike '%Olten%' or label ilike '%Studerweg%'",
        "plzo ilike '%Olten%' OR label ilike '%Studerweg%'",
        "label = 'Studerweg' and plzo not ilike '%Olten%'",
        "plzo = '8302 Kloten'",
        "plzo ilike '%Murten%'",
        "plzo ilike '%Basel%'",
        "plzo ilike '8302%'",
        "blah ilike '8302%'", # should not work
        "gdename ilike 'sel%'",
        "label ilike '%Hauptstrasse%'",
        "label ilike 'Im Heimatla%'", # 'Im Heimatland' in Basel
        "gdenr > 2701 and gdenr < 2704",
        "gdenr > 2701 and gdenr < 2704 and gdename = 'Seltisberg'", # should not return any results
    ],
    "ch.bfe.ladestellen-elektromobilitaet": [
        "IsOpen24Hours = true",
        "IsOpen24Hours is true",
        "QueryAuthenticationModes ilike '%nfc%'", 
        "Longitude > 7.476",
        "QueryAuthenticationModes ilike '%nfc%' and Longitude > 7.476",
    ]
}

find_examples = {
    "ch.swisstopo.amtliches-strassenverzeichnis": [
#         {"searchText": "Studerweg", "searchField": "label", "layerDefs": "plzo ilike '%Olten%'"},
    ]
}

BRANCH = 'layerdefs'

####################################
# Helpers
def encode_param(query):
    return urllib.parse.quote(query)

def decode_param(query):
    return urllib.parse.unquote(query)

def get_identify_url(params):
    """ params needs to be a dict of the form
    params = {
        "branch":'',
        "layer":'ch.swisstopo.amtliches-strassenverzeichnis',
        "paramName":'layerDefs',
        "paramValue":"plzo+=+'8302 Kloten'"
    }
    """
    _url = """https://mf-chsdi3.dev.bgdi.ch/
{branch}/
rest/services/all/MapServer/
identify?
geometry=2577070,1184860
&geometryType=esriGeometryPoint
&geometryFormat=geojson
&tolerance=500000
&mapExtent=0,0,100,100
&imageDisplay=100,100,100
&lang=de
&layers=all:{layer}
&returnGeometry=false
&sr=2056
&{paramName}={paramValue}
    """
    url = _url.format(**params).strip().replace('\n','')
    return url

def get_find_url(params):
    """ params needs to be a dict of the form
    params = {
        "branch":'',
        "layer":'ch.swisstopo.amtliches-strassenverzeichnis',
        "paramName":'layerDefs',
        "paramValue":"plzo+=+'8302 Kloten'"
    }
    """
    _url = """https://mf-chsdi3.dev.bgdi.ch/
{branch}/
rest/services/all/MapServer/
find?
layer={layer}
&searchText={searchText}
&searchField={searchField}
&returnGeometry=false
&contains=false
&{paramName}={paramValue}
    """
    url = _url.format(**params).strip().replace('\n','')
    return url
    
def get_url(variant, params):
    if variant == 'identify':
        url = get_identify_url(params)
    else:
        url = get_find_url(params)
    print("\n=================\nrequesting {}".format(decode_param(params['paramValue'])))
#     print(url)
    response = requests.get(url)
    if response.status_code == 200:
        results = response.json().get('results', [])
        print("--> success! {} result(s)".format(len(results)))

        # print the first result
        pprint.pprint(next(iter(results), []))

    else:
        print("--> example :{}: returned error {}: {}".format(example, response.status_code, response.text))

        
# for layer, layer_examples in identify_examples.items():
#     for example in layer_examples:
#         layerDefsDict = {layer:example}
#         layerDefs_params = {
#             "branch":BRANCH,
#             "layer":layer,
#             "paramName":'layerDefs',
#             "paramValue":encode_param(json.dumps(layerDefsDict))
#         }
#         print(get_identify_url(layerDefs_params))

# %% [markdown]
# ### Exceute requests

# %%
import json

for layer, layer_examples in identify_examples.items():
    for example in layer_examples:
        layerDefsDict = {layer:example}
        layerDefs_params = {
            "branch":BRANCH,
            "layer":layer,
            "paramName":'layerDefs',
            "paramValue":encode_param(json.dumps(layerDefsDict))
        }
        get_url('identify',layerDefs_params)

for layer, layer_examples in find_examples.items():
    for example in layer_examples:
        layerDefsDict = {layer:example['layerDefs']}
        layerDefs_params = {
            "branch":BRANCH,
            "layer":layer,
            "paramName":'layerDefs',
            "searchText": example['searchText'],
            "searchField": example['searchField'],            
            "paramValue":encode_param(json.dumps(layerDefsDict))
        }
        get_url('find',layerDefs_params)
# Out:
# =================
# requesting {"ch.bazl.luftfahrthindernis": "bgdi_activesince <= '2019-07-30'"}
# --> success! 201 result(s)
# {'featureId': 1881,
#  'id': 1881,
#  'layerBodId': 'ch.bazl.luftfahrthindernis',
#  'layerName': 'Luftfahrthindernisse',
#  'properties': {'abortionaccomplished': None,
#                 'bgdi_activesince': '1950-01-01',
#                 'bgdi_created': '19.08.2019',
#                 'duration': 'PERM',
#                 'geomtype': 'line',
#                 'label': '236-HL-26',
#                 'lk100': '33',
#                 'maxheightagl': 60,
#                 'obstacletype': 'Power line',
#                 'registrationnumber': '236-HL-26',
#                 'sanctiontext': 'No Marking and/or Lighting',
#                 'startofconstruction': '1950-01-01',
#                 'state': 'A',
#                 'topelevationamsl': 422,
#                 'totallength': 97}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "gdenr << 2704"}
# --> example :gdenr << 2704: returned error 400: {"status":"error","code":400,"detail":"The layerDefs clause is not valid for ch.swisstopo.amtliches-strassenverzeichnis."}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "gdenr != 2704"}
# --> success! 201 result(s)
# {'featureId': 6497188,
#  'id': 6497188,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10243420,
#                 'gdename': 'Lugano',
#                 'gdenr': 5192,
#                 'label': 'Piazza da Bögn',
#                 'plzo': '6951 Bogno',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo ilike '%Olten%' and label ilike '%Studerweg%'"}
# --> success! 1 result(s)
# {'featureId': 6569342,
#  'id': 6569342,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10025593,
#                 'gdename': 'Olten',
#                 'gdenr': 2581,
#                 'label': 'Studerweg',
#                 'plzo': '4600 Olten',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo ilike '%Olten%' and label ilike '%Studerwe'"}
# --> success! 0 result(s)
# []
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo ilike '%Olten%' or label ilike '%Studerweg%'"}
# --> success! 201 result(s)
# {'featureId': 6555796,
#  'id': 6555796,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10021184,
#                 'gdename': 'Sattel',
#                 'gdenr': 1371,
#                 'label': 'Studerweg',
#                 'plzo': '6417 Sattel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo ilike '%Olten%' OR label ilike '%Studerweg%'"}
# --> success! 201 result(s)
# {'featureId': 6555796,
#  'id': 6555796,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10021184,
#                 'gdename': 'Sattel',
#                 'gdenr': 1371,
#                 'label': 'Studerweg',
#                 'plzo': '6417 Sattel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "label = 'Studerweg' and plzo not ilike '%Olten%'"}
# --> success! 6 result(s)
# {'featureId': 6555796,
#  'id': 6555796,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10021184,
#                 'gdename': 'Sattel',
#                 'gdenr': 1371,
#                 'label': 'Studerweg',
#                 'plzo': '6417 Sattel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo = '8302 Kloten'"}
# --> success! 201 result(s)
# {'featureId': 6584632,
#  'id': 6584632,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10127954,
#                 'gdename': 'Kloten',
#                 'gdenr': 62,
#                 'label': 'Flurstrasse',
#                 'plzo': '8302 Kloten',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo ilike '%Murten%'"}
# --> success! 201 result(s)
# {'featureId': 6673467,
#  'id': 6673467,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10191564,
#                 'gdename': 'Murten',
#                 'gdenr': 2275,
#                 'label': 'Burgunderstrasse',
#                 'plzo': '3280 Murten',
#                 'status': 'gültig',
#                 'type': 'Benanntes Gebiet',
#                 'validated': 0}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo ilike '%Basel%'"}
# --> success! 201 result(s)
# {'featureId': 6468056,
#  'id': 6468056,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10025111,
#                 'gdename': 'Basel',
#                 'gdenr': 2701,
#                 'label': 'Turnerstrasse',
#                 'plzo': '4058 Basel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "plzo ilike '8302%'"}
# --> success! 201 result(s)
# {'featureId': 6584632,
#  'id': 6584632,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10127954,
#                 'gdename': 'Kloten',
#                 'gdenr': 62,
#                 'label': 'Flurstrasse',
#                 'plzo': '8302 Kloten',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "blah ilike '8302%'"}
# --> example :blah ilike '8302%': returned error 400: {"status":"error","code":400,"detail":"Query attribute 'blah' is not queryable. Queryable attributes are 'label,plzo,gdename,gdenr,type'"}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "gdename ilike 'sel%'"}
# --> success! 201 result(s)
# {'featureId': 6471477,
#  'id': 6471477,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10175906,
#                 'gdename': 'Seltisberg',
#                 'gdenr': 2833,
#                 'label': 'Im Doktorgarten',
#                 'plzo': '4411 Seltisberg',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "label ilike '%Hauptstrasse%'"}
# --> success! 201 result(s)
# {'featureId': 6526591,
#  'id': 6526591,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10057626,
#                 'gdename': 'Walperswil',
#                 'gdenr': 754,
#                 'label': 'Hauptstrasse',
#                 'plzo': '3272 Walperswil',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "label ilike 'Im Heimatla%'"}
# --> success! 1 result(s)
# {'featureId': 6468061,
#  'id': 6468061,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10087625,
#                 'gdename': 'Basel',
#                 'gdenr': 2701,
#                 'label': 'Im Heimatland',
#                 'plzo': '4058 Basel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "gdenr > 2701 and gdenr < 2704"}
# --> success! 201 result(s)
# {'featureId': 6468057,
#  'id': 6468057,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10181514,
#                 'gdename': 'Riehen',
#                 'gdenr': 2703,
#                 'label': 'Grendelgasse',
#                 'plzo': '4125 Riehen',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting {"ch.swisstopo.amtliches-strassenverzeichnis": "gdenr > 2701 and gdenr < 2704 and gdename = 'Seltisberg'"}
# --> success! 0 result(s)
# []
#
# =================
# requesting {"ch.bfe.ladestellen-elektromobilitaet": "IsOpen24Hours = true"}
# --> example :IsOpen24Hours = true: returned error 400: {"status":"error","code":400,"detail":"No GeoTable was found for ch.bfe.ladestellen-elektromobilitaet"}
#
# =================
# requesting {"ch.bfe.ladestellen-elektromobilitaet": "IsOpen24Hours is true"}
# --> example :IsOpen24Hours is true: returned error 400: {"status":"error","code":400,"detail":"No GeoTable was found for ch.bfe.ladestellen-elektromobilitaet"}
#
# =================
# requesting {"ch.bfe.ladestellen-elektromobilitaet": "QueryAuthenticationModes ilike '%nfc%'"}
# --> example :QueryAuthenticationModes ilike '%nfc%': returned error 400: {"status":"error","code":400,"detail":"No GeoTable was found for ch.bfe.ladestellen-elektromobilitaet"}
#
# =================
# requesting {"ch.bfe.ladestellen-elektromobilitaet": "Longitude > 7.476"}
# --> example :Longitude > 7.476: returned error 400: {"status":"error","code":400,"detail":"No GeoTable was found for ch.bfe.ladestellen-elektromobilitaet"}
#
# =================
# requesting {"ch.bfe.ladestellen-elektromobilitaet": "QueryAuthenticationModes ilike '%nfc%' and Longitude > 7.476"}
# --> example :QueryAuthenticationModes ilike '%nfc%' and Longitude > 7.476: returned error 400: {"status":"error","code":400,"detail":"No GeoTable was found for ch.bfe.ladestellen-elektromobilitaet"}

# %% [markdown]
# ## where
# **Note: the `where` parameter is DEPRECATED! Use layerdefs instead**
#
# When using `where` as query param, the filter expression with the attribute(s) contained in the layer specified for identify are directly passed, e.g.
# ```
# &where=plzo+=+'8302 Kloten'
# ```
#
# ### Examples

# %%
for layer, layer_examples in identify_examples.items():
    for example in layer_examples:
        where_params = {
            "branch":BRANCH,
            "paramName":'where',
            "layer":layer,
            "paramValue":encode_param(example)
        }
        get_url('identify',where_params)
# Out:
# =================
# requesting bgdi_activesince <= '2019-07-30'
# --> success! 201 result(s)
# {'featureId': 1881,
#  'id': 1881,
#  'layerBodId': 'ch.bazl.luftfahrthindernis',
#  'layerName': 'Luftfahrthindernisse',
#  'properties': {'abortionaccomplished': None,
#                 'bgdi_activesince': '1950-01-01',
#                 'bgdi_created': '19.08.2019',
#                 'duration': 'PERM',
#                 'geomtype': 'line',
#                 'label': '236-HL-26',
#                 'lk100': '33',
#                 'maxheightagl': 60,
#                 'obstacletype': 'Power line',
#                 'registrationnumber': '236-HL-26',
#                 'sanctiontext': 'No Marking and/or Lighting',
#                 'startofconstruction': '1950-01-01',
#                 'state': 'A',
#                 'topelevationamsl': 422,
#                 'totallength': 97}}
#
# =================
# requesting plzo ilike '%Olten%' and label ilike '%Studerweg%'
# --> success! 1 result(s)
# {'featureId': 6569342,
#  'id': 6569342,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10025593,
#                 'gdename': 'Olten',
#                 'gdenr': 2581,
#                 'label': 'Studerweg',
#                 'plzo': '4600 Olten',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting plzo ilike '%Olten%' and label ilike '%Studerwe'
# --> success! 0 result(s)
# []
#
# =================
# requesting plzo ilike '%Olten%' or label ilike '%Studerweg%'
# --> success! 201 result(s)
# {'featureId': 6555796,
#  'id': 6555796,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10021184,
#                 'gdename': 'Sattel',
#                 'gdenr': 1371,
#                 'label': 'Studerweg',
#                 'plzo': '6417 Sattel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting plzo ilike '%Olten%' OR label ilike '%Studerweg%'
# --> success! 201 result(s)
# {'featureId': 6555796,
#  'id': 6555796,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10021184,
#                 'gdename': 'Sattel',
#                 'gdenr': 1371,
#                 'label': 'Studerweg',
#                 'plzo': '6417 Sattel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting label = 'Studerweg' and plzo not ilike '%Olten%'
# --> success! 6 result(s)
# {'featureId': 6555796,
#  'id': 6555796,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10021184,
#                 'gdename': 'Sattel',
#                 'gdenr': 1371,
#                 'label': 'Studerweg',
#                 'plzo': '6417 Sattel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting plzo = '8302 Kloten'
# --> success! 201 result(s)
# {'featureId': 6584632,
#  'id': 6584632,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10127954,
#                 'gdename': 'Kloten',
#                 'gdenr': 62,
#                 'label': 'Flurstrasse',
#                 'plzo': '8302 Kloten',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting plzo ilike '%Murten%'
# --> success! 201 result(s)
# {'featureId': 6673467,
#  'id': 6673467,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10191564,
#                 'gdename': 'Murten',
#                 'gdenr': 2275,
#                 'label': 'Burgunderstrasse',
#                 'plzo': '3280 Murten',
#                 'status': 'gültig',
#                 'type': 'Benanntes Gebiet',
#                 'validated': 0}}
#
# =================
# requesting plzo ilike '%Basel%'
# --> success! 201 result(s)
# {'featureId': 6468056,
#  'id': 6468056,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10025111,
#                 'gdename': 'Basel',
#                 'gdenr': 2701,
#                 'label': 'Turnerstrasse',
#                 'plzo': '4058 Basel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting plzo ilike '8302%'
# --> success! 201 result(s)
# {'featureId': 6584632,
#  'id': 6584632,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10127954,
#                 'gdename': 'Kloten',
#                 'gdenr': 62,
#                 'label': 'Flurstrasse',
#                 'plzo': '8302 Kloten',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting blah ilike '8302%'
# --> example :blah ilike '8302%': returned error 400: {"status":"error","code":400,"detail":"Query attribute 'blah' is not queryable. Queryable attributes are 'label,plzo,gdename,gdenr,type'"}
#
# =================
# requesting gdename ilike 'sel%'
# --> success! 201 result(s)
# {'featureId': 6471477,
#  'id': 6471477,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10175906,
#                 'gdename': 'Seltisberg',
#                 'gdenr': 2833,
#                 'label': 'Im Doktorgarten',
#                 'plzo': '4411 Seltisberg',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting label ilike '%Hauptstrasse%'
# --> success! 201 result(s)
# {'featureId': 6526591,
#  'id': 6526591,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10057626,
#                 'gdename': 'Walperswil',
#                 'gdenr': 754,
#                 'label': 'Hauptstrasse',
#                 'plzo': '3272 Walperswil',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 0}}
#
# =================
# requesting label ilike 'Im Heimatla%'
# --> success! 1 result(s)
# {'featureId': 6468061,
#  'id': 6468061,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10087625,
#                 'gdename': 'Basel',
#                 'gdenr': 2701,
#                 'label': 'Im Heimatland',
#                 'plzo': '4058 Basel',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting gdenr > 2701 and gdenr < 2704
# --> success! 201 result(s)
# {'featureId': 6468057,
#  'id': 6468057,
#  'layerBodId': 'ch.swisstopo.amtliches-strassenverzeichnis',
#  'layerName': 'Amtliches Strassenverzeichnis',
#  'properties': {'esid': 10181514,
#                 'gdename': 'Riehen',
#                 'gdenr': 2703,
#                 'label': 'Grendelgasse',
#                 'plzo': '4125 Riehen',
#                 'status': 'gültig',
#                 'type': 'Strasse',
#                 'validated': 1}}
#
# =================
# requesting gdenr > 2701 and gdenr < 2704 and gdename = 'Seltisberg'
# --> success! 0 result(s)
# []
#
# =================
# requesting IsOpen24Hours = true
# --> success! 201 result(s)
# {'featureId': 162305,
#  'id': 162305,
#  'layerBodId': 'ch.bfe.ladestellen-elektromobilitaet',
#  'layerName': 'Ladestellen E-Mobilität (im Aufbau)',
#  'properties': {'Accessibility': 'Unspecified',
#                 'AdditionalInfo': None,
#                 'Address': None,
#                 'AuthenticationModes': ['REMOTE',
#                                         'NFC RFID Classic',
#                                         'Direct Payment'],
#                 'Availability': 'Available',
#                 'ChargingFacilities': None,
#                 'ChargingModes': ['Mode_3'],
#                 'ChargingStationID': 'CH*SWIEE1006',
#                 'CharingStationName': 'CH*SWIEE1006',
#                 'City': '9200 Gossau',
#                 'DynamicInfoAvailable': 'true',
#                 'EvseID': 'CH*SWIEE1006',
#                 'GeoCoordinates': '47.4161,9.247879',
#                 'HouseNum': None,
#                 'IsHubjectCompatible': True,
#                 'IsOpen24Hours': True,
#                 'LastUpdate': None,
#                 'Latitude': 47.4161,
#                 'Longitude': 9.247879,
#                 'MaxCapacity': 22,
#                 'OpeningTimes': None,
#                 'OperatorID': 'CH*SWISSCHARGE',
#                 'OperatorName': 'Swisscharge',
#                 'PaymentOptions': None,
#                 'Plugs': ['Type 2 Outlet'],
#                 'PostalCode': None,
#                 'ProviderURL': 'https://www.swisscharge.ch',
#                 'QueryAuthenticationModes': 'REMOTE NFC RFID Classic Direct '
#                                             'Payment',
#                 'QueryChargingFacilities': None,
#                 'QueryChargingModes': 'Mode_3',
#                 'QueryPaymentOptions': None,
#                 'QueryPlugs': 'Type 2 Outlet',
#                 'Street': 'Tellstrasse 5',
#                 'label': 'CH*SWIEE1006'}}
#
# =================
# requesting IsOpen24Hours is true
# --> success! 201 result(s)
# {'featureId': 162305,
#  'id': 162305,
#  'layerBodId': 'ch.bfe.ladestellen-elektromobilitaet',
#  'layerName': 'Ladestellen E-Mobilität (im Aufbau)',
#  'properties': {'Accessibility': 'Unspecified',
#                 'AdditionalInfo': None,
#                 'Address': None,
#                 'AuthenticationModes': ['REMOTE',
#                                         'NFC RFID Classic',
#                                         'Direct Payment'],
#                 'Availability': 'Available',
#                 'ChargingFacilities': None,
#                 'ChargingModes': ['Mode_3'],
#                 'ChargingStationID': 'CH*SWIEE1006',
#                 'CharingStationName': 'CH*SWIEE1006',
#                 'City': '9200 Gossau',
#                 'DynamicInfoAvailable': 'true',
#                 'EvseID': 'CH*SWIEE1006',
#                 'GeoCoordinates': '47.4161,9.247879',
#                 'HouseNum': None,
#                 'IsHubjectCompatible': True,
#                 'IsOpen24Hours': True,
#                 'LastUpdate': None,
#                 'Latitude': 47.4161,
#                 'Longitude': 9.247879,
#                 'MaxCapacity': 22,
#                 'OpeningTimes': None,
#                 'OperatorID': 'CH*SWISSCHARGE',
#                 'OperatorName': 'Swisscharge',
#                 'PaymentOptions': None,
#                 'Plugs': ['Type 2 Outlet'],
#                 'PostalCode': None,
#                 'ProviderURL': 'https://www.swisscharge.ch',
#                 'QueryAuthenticationModes': 'REMOTE NFC RFID Classic Direct '
#                                             'Payment',
#                 'QueryChargingFacilities': None,
#                 'QueryChargingModes': 'Mode_3',
#                 'QueryPaymentOptions': None,
#                 'QueryPlugs': 'Type 2 Outlet',
#                 'Street': 'Tellstrasse 5',
#                 'label': 'CH*SWIEE1006'}}
#
# =================
# requesting QueryAuthenticationModes ilike '%nfc%'
# --> success! 201 result(s)
# {'featureId': 162305,
#  'id': 162305,
#  'layerBodId': 'ch.bfe.ladestellen-elektromobilitaet',
#  'layerName': 'Ladestellen E-Mobilität (im Aufbau)',
#  'properties': {'Accessibility': 'Unspecified',
#                 'AdditionalInfo': None,
#                 'Address': None,
#                 'AuthenticationModes': ['REMOTE',
#                                         'NFC RFID Classic',
#                                         'Direct Payment'],
#                 'Availability': 'Available',
#                 'ChargingFacilities': None,
#                 'ChargingModes': ['Mode_3'],
#                 'ChargingStationID': 'CH*SWIEE1006',
#                 'CharingStationName': 'CH*SWIEE1006',
#                 'City': '9200 Gossau',
#                 'DynamicInfoAvailable': 'true',
#                 'EvseID': 'CH*SWIEE1006',
#                 'GeoCoordinates': '47.4161,9.247879',
#                 'HouseNum': None,
#                 'IsHubjectCompatible': True,
#                 'IsOpen24Hours': True,
#                 'LastUpdate': None,
#                 'Latitude': 47.4161,
#                 'Longitude': 9.247879,
#                 'MaxCapacity': 22,
#                 'OpeningTimes': None,
#                 'OperatorID': 'CH*SWISSCHARGE',
#                 'OperatorName': 'Swisscharge',
#                 'PaymentOptions': None,
#                 'Plugs': ['Type 2 Outlet'],
#                 'PostalCode': None,
#                 'ProviderURL': 'https://www.swisscharge.ch',
#                 'QueryAuthenticationModes': 'REMOTE NFC RFID Classic Direct '
#                                             'Payment',
#                 'QueryChargingFacilities': None,
#                 'QueryChargingModes': 'Mode_3',
#                 'QueryPaymentOptions': None,
#                 'QueryPlugs': 'Type 2 Outlet',
#                 'Street': 'Tellstrasse 5',
#                 'label': 'CH*SWIEE1006'}}
#
# =================
# requesting Longitude > 7.476
# --> success! 201 result(s)
# {'featureId': 162305,
#  'id': 162305,
#  'layerBodId': 'ch.bfe.ladestellen-elektromobilitaet',
#  'layerName': 'Ladestellen E-Mobilität (im Aufbau)',
#  'properties': {'Accessibility': 'Unspecified',
#                 'AdditionalInfo': None,
#                 'Address': None,
#                 'AuthenticationModes': ['REMOTE',
#                                         'NFC RFID Classic',
#                                         'Direct Payment'],
#                 'Availability': 'Available',
#                 'ChargingFacilities': None,
#                 'ChargingModes': ['Mode_3'],
#                 'ChargingStationID': 'CH*SWIEE1006',
#                 'CharingStationName': 'CH*SWIEE1006',
#                 'City': '9200 Gossau',
#                 'DynamicInfoAvailable': 'true',
#                 'EvseID': 'CH*SWIEE1006',
#                 'GeoCoordinates': '47.4161,9.247879',
#                 'HouseNum': None,
#                 'IsHubjectCompatible': True,
#                 'IsOpen24Hours': True,
#                 'LastUpdate': None,
#                 'Latitude': 47.4161,
#                 'Longitude': 9.247879,
#                 'MaxCapacity': 22,
#                 'OpeningTimes': None,
#                 'OperatorID': 'CH*SWISSCHARGE',
#                 'OperatorName': 'Swisscharge',
#                 'PaymentOptions': None,
#                 'Plugs': ['Type 2 Outlet'],
#                 'PostalCode': None,
#                 'ProviderURL': 'https://www.swisscharge.ch',
#                 'QueryAuthenticationModes': 'REMOTE NFC RFID Classic Direct '
#                                             'Payment',
#                 'QueryChargingFacilities': None,
#                 'QueryChargingModes': 'Mode_3',
#                 'QueryPaymentOptions': None,
#                 'QueryPlugs': 'Type 2 Outlet',
#                 'Street': 'Tellstrasse 5',
#                 'label': 'CH*SWIEE1006'}}
#
# =================
# requesting QueryAuthenticationModes ilike '%nfc%' and Longitude > 7.476
# --> success! 201 result(s)
# {'featureId': 162305,
#  'id': 162305,
#  'layerBodId': 'ch.bfe.ladestellen-elektromobilitaet',
#  'layerName': 'Ladestellen E-Mobilität (im Aufbau)',
#  'properties': {'Accessibility': 'Unspecified',
#                 'AdditionalInfo': None,
#                 'Address': None,
#                 'AuthenticationModes': ['REMOTE',
#                                         'NFC RFID Classic',
#                                         'Direct Payment'],
#                 'Availability': 'Available',
#                 'ChargingFacilities': None,
#                 'ChargingModes': ['Mode_3'],
#                 'ChargingStationID': 'CH*SWIEE1006',
#                 'CharingStationName': 'CH*SWIEE1006',
#                 'City': '9200 Gossau',
#                 'DynamicInfoAvailable': 'true',
#                 'EvseID': 'CH*SWIEE1006',
#                 'GeoCoordinates': '47.4161,9.247879',
#                 'HouseNum': None,
#                 'IsHubjectCompatible': True,
#                 'IsOpen24Hours': True,
#                 'LastUpdate': None,
#                 'Latitude': 47.4161,
#                 'Longitude': 9.247879,
#                 'MaxCapacity': 22,
#                 'OpeningTimes': None,
#                 'OperatorID': 'CH*SWISSCHARGE',
#                 'OperatorName': 'Swisscharge',
#                 'PaymentOptions': None,
#                 'Plugs': ['Type 2 Outlet'],
#                 'PostalCode': None,
#                 'ProviderURL': 'https://www.swisscharge.ch',
#                 'QueryAuthenticationModes': 'REMOTE NFC RFID Classic Direct '
#                                             'Payment',
#                 'QueryChargingFacilities': None,
#                 'QueryChargingModes': 'Mode_3',
#                 'QueryPaymentOptions': None,
#                 'QueryPlugs': 'Type 2 Outlet',
#                 'Street': 'Tellstrasse 5',
#                 'label': 'CH*SWIEE1006'}}

# %% [markdown]
# ## sqlinjection risk
#
# This kind of filtering possibly opens the door for sql injections. The current implementation (which is the same for where and layerDefs) uses a strict and restrictive grammer to parse allowed expressions. The following cases must not work:

# %%
sqlinj = {
    "ch.swisstopo.amtliches-strassenverzeichnis": [
        "plzo ilike '%Olten%' and 1=1",
        "1=1",
        "true=true"
    ]
}
for layer, layer_examples in sqlinj.items():
    for example in layer_examples:
        where_params = {
            "branch":BRANCH,
            "paramName":'where',
            "layer":layer,
            "paramValue":encode_param(example)
        }
        get_url('identify',where_params)
# Out:
# =================
# requesting plzo ilike '%Olten%' and 1=1
# --> example :plzo ilike '%Olten%' and 1=1: returned error 400: {"status":"error","code":400,"detail":"The where/layerDefs clause is not valid for ch.swisstopo.amtliches-strassenverzeichnis."}
#
# =================
# requesting 1=1
# --> example :1=1: returned error 400: {"status":"error","code":400,"detail":"The where/layerDefs clause is not valid for ch.swisstopo.amtliches-strassenverzeichnis."}
#
# =================
# requesting true=true
# --> example :true=true: returned error 400: {"status":"error","code":400,"detail":"Query attribute 'true' is not queryable. Queryable attributes are 'label,plzo,gdename,gdenr,type'"}

# %% [markdown]
# ### Open questions
#
#
# - who is using where other than frontend?
# - how to configure in bod to identify layer that is visualized as json but queryable?
# - street number? (not included in label, included at all in strassenverz.?)

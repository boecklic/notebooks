# %% [markdown]
# # WebMapService

# %%
from owslib.wms import WebMapService
wms = WebMapService('http://wms.swisstopo.admin.ch/', version='1.3.0', username="user_brl6a", password="58wbytpjt1a2gz4m")
print('{} (type: {}) contains {} layers'.format(wms.identification.title, wms.identification.type, len(wms.contents)))
# Out:
# swisstopo WMS (type: WMS) contains 107 layers

# %%
for layer_key,layer in wms.contents.items():
    print('{}: {}'.format(layer_key, layer.title))
# Out:
# WMS-SWISSTOPOWMS: swisstopo WMS
# ch.swisstopo.swissbathy3d-reliefschattierung: swissBATHY3D Reliefschattierung
# ch.swisstopo.swissbathy3d-reliefschattierung_getfeatureinfo: swissBATHY3D Reliefschattierung - ch.swisstopo.swissbathy3d-reliefschattierung_getfeatureinfo
# ch.swisstopo.swissbathy3d-reliefschattierung_getmap: swissBATHY3D Reliefschattierung - ch.swisstopo.swissbathy3d-reliefschattierung_getmap
# ch.swisstopo.swisstlm3d-eisenbahnnetz: Eisenbahn swissTLM3D
# ch.swisstopo.swisstlm3d-gewaessernetz: Gewässer swissTLM3D
# ch.swisstopo.swisstlm3d-gewaessernetz_lake: Gewässer swissTLM3D - ch.swisstopo.swisstlm3d-gewaessernetz_lake
# ch.swisstopo.swisstlm3d-gewaessernetz_line: Gewässer swissTLM3D - ch.swisstopo.swisstlm3d-gewaessernetz_line
# ch.swisstopo.swisstlm3d-strassen: Strassen und Wege swissTLM3D
# ch.swisstopo.swisstlm3d-strassen_strasse: Strassen und Wege swissTLM3D - ch.swisstopo.swisstlm3d-strassen_strasse
# ch.swisstopo.swisstlm3d-strassen_aus_einfahrt: Strassen und Wege swissTLM3D - ch.swisstopo.swisstlm3d-strassen_aus_einfahrt
# ch.swisstopo.swisstlm3d-strassen_strasseninfo: Strassen und Wege swissTLM3D - ch.swisstopo.swisstlm3d-strassen_strasseninfo
# ch.swisstopo.swisstlm3d-strassen_legende: Strassen und Wege swissTLM3D - ch.swisstopo.swisstlm3d-strassen_legende
# ch.swisstopo.swisstlm3d-uebrigerverkehr: Seilbahnen swissTLM3D
# ch.swisstopo.hiks-dufour: Dufourkarte Erstausgabe
# ch.swisstopo.hiks-siegfried: Siegfriedkarte Erstausgabe
# ch.swisstopo.hiks-siegfried.detail: Siegfriedkarte Erstausgabe - ch.swisstopo.hiks-siegfried.detail
# ch.swisstopo.hiks-siegfried.overview: Siegfriedkarte Erstausgabe - ch.swisstopo.hiks-siegfried.overview
# ch.swisstopo.geologie-geologischer_atlas: Geologischer Atlas GA25
# ch.swisstopo.images-swissimage.metadata: Einteilung SWISSIMAGE 25 cm Raster
# ch.swisstopo.images-swissimage.metadata-kartenblatt: Einteilung SWISSIMAGE 25 cm Raster - ch.swisstopo.images-swissimage.metadata-kartenblatt
# ch.swisstopo.images-swissimage.metadata-kartenblatt_name: Einteilung SWISSIMAGE 25 cm Raster - ch.swisstopo.images-swissimage.metadata-kartenblatt_name
# ch.swisstopo.images-swissimage.metadata-kartenblatt_nummer: Einteilung SWISSIMAGE 25 cm Raster - ch.swisstopo.images-swissimage.metadata-kartenblatt_nummer
# ch.swisstopo.pixelkarte-pk25.metadata: Einteilung Landeskarte 25 Raster
# ch.swisstopo.pixelkarte-pk25.metadata-kartenblatt: Einteilung Landeskarte 25 Raster - ch.swisstopo.pixelkarte-pk25.metadata-kartenblatt
# ch.swisstopo.pixelkarte-pk25.metadata-kartenblatt_name: Einteilung Landeskarte 25 Raster - ch.swisstopo.pixelkarte-pk25.metadata-kartenblatt_name
# ch.swisstopo.pixelkarte-pk25.metadata-kartenblatt_nummer: Einteilung Landeskarte 25 Raster - ch.swisstopo.pixelkarte-pk25.metadata-kartenblatt_nummer
# ch.swisstopo.pixelkarte-pk50.metadata: Einteilung Landeskarte 50 Raster
# ch.swisstopo.pixelkarte-pk50.metadata-kartenblatt: Einteilung Landeskarte 50 Raster - ch.swisstopo.pixelkarte-pk50.metadata-kartenblatt
# ch.swisstopo.pixelkarte-pk50.metadata-kartenblatt_name: Einteilung Landeskarte 50 Raster - ch.swisstopo.pixelkarte-pk50.metadata-kartenblatt_name
# ch.swisstopo.pixelkarte-pk50.metadata-kartenblatt_nummer: Einteilung Landeskarte 50 Raster - ch.swisstopo.pixelkarte-pk50.metadata-kartenblatt_nummer
# ch.swisstopo.pixelkarte-pk100.metadata: Einteilung Landeskarte 100 Raster
# ch.swisstopo.pixelkarte-pk100.metadata-kartenblatt: Einteilung Landeskarte 100 Raster - ch.swisstopo.pixelkarte-pk100.metadata-kartenblatt
# ch.swisstopo.pixelkarte-pk100.metadata-kartenblatt_name: Einteilung Landeskarte 100 Raster - ch.swisstopo.pixelkarte-pk100.metadata-kartenblatt_name
# ch.swisstopo.pixelkarte-pk100.metadata-kartenblatt_nummer: Einteilung Landeskarte 100 Raster - ch.swisstopo.pixelkarte-pk100.metadata-kartenblatt_nummer
# ch.swisstopo.pixelkarte-pk200.metadata: Einteilung Landeskarte 200 Raster
# ch.swisstopo.pixelkarte-pk200.metadata-kartenblatt: Einteilung Landeskarte 200 Raster - ch.swisstopo.pixelkarte-pk200.metadata-kartenblatt
# ch.swisstopo.pixelkarte-pk200.metadata-kartenblatt_name: Einteilung Landeskarte 200 Raster - ch.swisstopo.pixelkarte-pk200.metadata-kartenblatt_name
# ch.swisstopo.pixelkarte-pk200.metadata-kartenblatt_nummer: Einteilung Landeskarte 200 Raster - ch.swisstopo.pixelkarte-pk200.metadata-kartenblatt_nummer
# ch.swisstopo.pixelkarte-pk500.metadata: Einteilung Landeskarte 500 Raster
# ch.swisstopo.pixelkarte-pk500.metadata-kartenblatt: Einteilung Landeskarte 500 Raster - ch.swisstopo.pixelkarte-pk500.metadata-kartenblatt
# ch.swisstopo.pixelkarte-pk500.metadata-kartenblatt_name: Einteilung Landeskarte 500 Raster - ch.swisstopo.pixelkarte-pk500.metadata-kartenblatt_name
# ch.swisstopo.pixelkarte-pk500.metadata-kartenblatt_nummer: Einteilung Landeskarte 500 Raster - ch.swisstopo.pixelkarte-pk500.metadata-kartenblatt_nummer
# ch.swisstopo.pixelkarte-pk1000.metadata: Einteilung Landeskarte 1:1 Mio.
# ch.swisstopo.pixelkarte-pk1000.metadata-kartenblatt: Einteilung Landeskarte 1:1 Mio. - ch.swisstopo.pixelkarte-pk1000.metadata-kartenblatt
# ch.swisstopo.pixelkarte-pk1000.metadata-kartenblatt_name: Einteilung Landeskarte 1:1 Mio. - ch.swisstopo.pixelkarte-pk1000.metadata-kartenblatt_name
# ch.swisstopo.pixelkarte-pk1000.metadata-kartenblatt_nummer: Einteilung Landeskarte 1:1 Mio. - ch.swisstopo.pixelkarte-pk1000.metadata-kartenblatt_nummer
# ch.swisstopo.swissimage: SWISSIMAGE Hintergrund
# ch.swisstopo.images-swissimage: SWISSIMAGE Hintergrund - ch.swisstopo.images-swissimage
# ch.swisstopo.pixelkarte-farbe: Landeskarten (farbig)
# ch.swisstopo.pixelkarte-grau: Landeskarten (grau)
# ch.swisstopo.swissalti3d-reliefschattierung: swissALTI3D Reliefschattierung
# ch.swisstopo.swisstlm3d-karte-farbe: Karte swissTLM (farbig)
# ch.swisstopo.swisstlm3d-karte-grau: Karte swissTLM (grau)
# ch.bazl.luftfahrtkarten-icao: Luftfahrtkarte ICAO
# ch.bazl.segelflugkarte: Segelflugkarte
# ch.swisstopo.tlm-swissboundaries: swissBOUNDARIES3D
# ch.swisstopo.swissboundaries3d-gemeinde-flaeche: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-gemeinde-flaeche
# ch.swisstopo.swissboundaries3d-gemeinde-grenze: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-gemeinde-grenze
# ch.swisstopo.swissboundaries3d-gemeinde-name: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-gemeinde-name
# ch.swisstopo.swissboundaries3d-bezirk-flaeche: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-bezirk-flaeche
# ch.swisstopo.swissboundaries3d-bezirk-grenze: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-bezirk-grenze
# ch.swisstopo.swissboundaries3d-bezirk-name: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-bezirk-name
# ch.swisstopo.swissboundaries3d-kanton-flaeche: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-kanton-flaeche
# ch.swisstopo.swissboundaries3d-kanton-grenze: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-kanton-grenze
# ch.swisstopo.swissboundaries3d-kanton-name: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-kanton-name
# ch.swisstopo.swissboundaries3d-land-flaeche: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-land-flaeche
# ch.swisstopo.swissboundaries3d-land-grenze: swissBOUNDARIES3D - ch.swisstopo.swissboundaries3d-land-grenze
# ch.swisstopo.swisstlm3d-wanderwege: Wanderwege
# ch.swisstopo.vec200-building: Einzelgebäude gen. swissTLMRegio
# ch.swisstopo.vec200-miscellaneous: Einzelobjekte swissTLMRegio
# ch.swisstopo.vec200-miscellaneous-builtupp: Einzelobjekte swissTLMRegio - ch.swisstopo.vec200-miscellaneous-builtupp
# ch.swisstopo.vec200-miscellaneous-physl: Einzelobjekte swissTLMRegio - ch.swisstopo.vec200-miscellaneous-physl
# ch.swisstopo.vec200-miscellaneous-poi: Einzelobjekte swissTLMRegio - ch.swisstopo.vec200-miscellaneous-poi
# ch.swisstopo.vec200-miscellaneous-supply: Einzelobjekte swissTLMRegio - ch.swisstopo.vec200-miscellaneous-supply
# ch.swisstopo.vec200-miscellaneous-geodpoint: Höhenkoten swissTLMRegio
# ch.swisstopo.vec200-names-namedlocation: Namen swissTLMRegio
# ch.swisstopo.vec200-adminboundaries-protectedarea: Schutzgebiete swissTLMRegio
# ch.swisstopo.vec200-landcover: Prim. Bodenbedeckung swissTLMRegio
# ch.swisstopo.vec200-transportation-strassennetz: Strassennetz swissTLMRegio
# ch.swisstopo.vec200-transportation-road: Strassennetz swissTLMRegio - ch.swisstopo.vec200-transportation-road
# ch.swisstopo.vec200-transportation-ramp: Strassennetz swissTLMRegio - ch.swisstopo.vec200-transportation-ramp
# ch.swisstopo.vec200-transportation-interchange: Strassennetz swissTLMRegio - ch.swisstopo.vec200-transportation-interchange
# ch.swisstopo.vec200-transportation-trafficinfo: Strassennetz swissTLMRegio - ch.swisstopo.vec200-transportation-trafficinfo
# ch.swisstopo.vec200-transportation-ship-autofaehre: Strassennetz swissTLMRegio - ch.swisstopo.vec200-transportation-ship-autofaehre
# ch.swisstopo.vec200-transportation-customsoffice: Strassennetz swissTLMRegio - ch.swisstopo.vec200-transportation-customsoffice
# ch.swisstopo.vec200-transportation-oeffentliche-verkehr: Öffentlicher Verkehr swissTLMRegio
# ch.swisstopo.vec200-transportation-airport: Öffentlicher Verkehr swissTLMRegio - ch.swisstopo.vec200-transportation-airport
# ch.swisstopo.vec200-transportation-railway: Öffentlicher Verkehr swissTLMRegio - ch.swisstopo.vec200-transportation-railway
# ch.swisstopo.vec200-transportation-runway: Öffentlicher Verkehr swissTLMRegio - ch.swisstopo.vec200-transportation-runway
# ch.swisstopo.vec200-transportation-terminal: Öffentlicher Verkehr swissTLMRegio - ch.swisstopo.vec200-transportation-terminal
# ch.swisstopo.vec200-transportation-ship-kursschiff_linie: Öffentlicher Verkehr swissTLMRegio - ch.swisstopo.vec200-transportation-ship-kursschiff_linie
# ch.swisstopo.vec200-hydrography: Gewässernetz swissTLMRegio
# ch.swisstopo.vec200-hydrography-dam: Gewässernetz swissTLMRegio - ch.swisstopo.vec200-hydrography-dam
# ch.swisstopo.vec200-hydrography-flowingwater: Gewässernetz swissTLMRegio - ch.swisstopo.vec200-hydrography-flowingwater
# ch.swisstopo.vec200-hydrography-hydroinfo: Gewässernetz swissTLMRegio - ch.swisstopo.vec200-hydrography-hydroinfo
# ch.swisstopo.vec200-hydrography-lake: Gewässernetz swissTLMRegio - ch.swisstopo.vec200-hydrography-lake
# ch.swisstopo.vec200-hydrography-stagnantwater: Gewässernetz swissTLMRegio - ch.swisstopo.vec200-hydrography-stagnantwater
# ch.swisstopo.geologie-geocover: GeoCover - Vektordaten
# ch.swisstopo.hangneigung-ueber_30: Hangneigungsklassen ab 30°
# ch.swisstopo-karto.schneeschuhrouten: Schneeschuhrouten
# ch.swisstopo-karto.skitouren: Skirouten
# ch.swisstopo.landeskarte-farbe-10: Landeskarte 1:10`000 (farbig)
# ch.swisstopo.landeskarte-grau-10: Landeskarte 1:10`000 (grau)
# ch.swisstopo.pixelkarte-farbe-winter: Landeskarte Winter | LK10, LK25, LK50, LK100
# ch.swisstopo.swissimage-product_1946: SWISSIMAGE HIST 1946
# ch.swisstopo.vec25-gewaessernetz_referenz: Gewässernetz VECTOR25

# %%
# Specify the layer you want to view
# layer = 'ch.swisstopo.vec200-transportation-railway'
layer = 'ch.swisstopo.pixelkarte-farbe'

attrs = ['title', 'boundingBox', 'boundingBoxWGS84', 'styles']

for attr in attrs:
    print('{}: {}'.format(attr.ljust(20), getattr(wms[layer], attr)))
# usually always 'default'
# style = next(iter(wms[layer].styles))
img = wms.getmap(layers=[layer],
                 styles=['default'],
                 srs='EPSG:2056',
                 bbox=(2590000, 1190000, 2600000, 1200000),
                 size=(200, 200),
                 format='image/jpeg',
                 transparent=True
)
# print(img)
img_data = img.read()

from IPython.core.display import Image, display
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
    
display(Image(data=img_data, format='jpg', unconfined=True))
# Out:
# title               : Landeskarten (farbig)
# boundingBox         : (2100000.0, 1050000.0, 2850000.0, 1400000.0, 'EPSG:2056')
# boundingBoxWGS84    : (0.659965, 45.4183, 10.8344, 48.7495)
# styles              : {}

# %% [markdown]
# # WebMapTileService WMTS

# %%
# Note: KVP encoding (key-value-pair as in /?service=WMTS&request=GetCapabilities&version=1.3.0)
# is not implemented/supported by wmts.geo.admin.ch
from owslib.wmts import WebMapTileService
from owslib.util import openURL
from IPython.core.display import Image, display
# wmts = WebMapTileService('https://wmts1.geo.admin.ch/')
username = 'user_brl6a'
pw = '58wbytpjt1a2gz4m'
wmts = WebMapTileService('https://wmts.geo.admin.ch/EPSG/2056/1.0.0/WMTSCapabilities.xml', username=username, password=pw)
print("{} (type: {}, version: {})".format(wmts.identification.title, wmts.identification.type, wmts.identification.version))
layer = 'ch.swisstopo.pixelkarte-farbe'
# # Note: OWSlib doesn't correctly handle "custom" parameters like 'time', hence we have to use a workaround here
# tile = wmts.gettile(layer=layer,
#                     time='current',
#                     tilematrixset='2056',
#                     tilematrix='22',
#                     row='277',
#                     column='245',
#                     format="image/jpeg",
#                 )

## NOTE2: row and col are switched between 2056 and 21781
url = wmts.buildTileResource(layer=layer,
                    style='default',
                    tilematrixset='2056',
                    tilematrix='22',
                    column='277',         
                    row='245',
                    format="image/jpeg"
                )

# Note: this url still contains the parameter '{Time}'
# that has to be replaced with 'current'
resurl = url.replace('{Time}', 'current')

print("fetching {}".format(resurl))

tile = openURL(resurl, username=username, password=pw)

display(Image(data=tile.read(), format='jpg', unconfined=True))
# Out:
# WMTS BGDI (type: OGC WMTS, version: 1.0.0)
# fetching https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.pixelkarte-farbe/default/current/2056/22/277/245.jpeg

# %%
import requests
from IPython.core.display import Image, display
wmts_url = "{scheme}://{servername}/{protocolversion}/{layername}/{stylename}/{time}/{tilematrixset}/{tilesetid}/{tilerow}/{tilecol}.{formatext}"
def get_wmts_url(scheme='https', servername='wmts.geo.admin.ch', protocolversion='1.0.0', layername=None, stylename='default', time='current', tilematrixset='2056', tilesetid=None, tilerow=None, tilecol=None, formatext='jpeg'):
    return wmts_url.format(
        scheme=scheme,
        servername=servername,
        protocolversion=protocolversion,
        layername=layername,
        stylename=stylename,
        time=time,
        tilematrixset=tilematrixset,
        tilesetid=tilesetid,
        tilerow=tilerow,
        tilecol=tilecol,
        formatext=formatext
    )
url = get_wmts_url(layername='ch.swisstopo.pixelkarte-farbe', tilesetid=22, tilerow=277, tilecol=245)
print('fetching {}'.format(url))
resp = requests.get(url, headers={'referer': "https://ltboc.geo.admin.ch"})
display(Image(data=resp.content, format='jpg', unconfined=True))
RenderJSON(resp.headers.copy())
# Out:
# fetching https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.pixelkarte-farbe/default/current/2056/22/277/245.jpeg
# <div id="71a0ca5c-cd4f-4da8-9d99-8e3df9562b99" style="height: 300px; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#             renderjson.set_show_to_level(1)
#             document.getElementById('71a0ca5c-cd4f-4da8-9d99-8e3df9562b99').appendChild(renderjson({'Date': 'Mon, 14 Oct 2019 13:57:05 GMT', 'Content-Type': 'image/jpeg', 'Content-Length': '28513', 'Connection': 'keep-alive', 'Last-Modified': 'Mon, 06 May 2019 08:54:54 GMT', 'ETag': '"4ad5d83c8d0f7df79585623c91f9564e"', 'Accept-Ranges': 'bytes, bytes', 'Server': 'AmazonS3', 'Cache-Control': 'public, max-age=1800', 'Access-Control-Allow-Origin': '*', 'X-tiles-s3-cache': 'HIT', 'X-Varnish': '1741489', 'Age': '0', 'Via': '1.1 varnish-v4', 'X-Cache': 'MISS'}))
#         });</script>

# %% [markdown]
# # Alti Service

# %%
headers = {'referer': "http://ltboc.geo.admin.ch"}
base_url = 'https://api3.geo.admin.ch/rest/services/height?easting={easting}&northing={northing}'
easting = "2597798.2"
northing = "1193085.1"
url = base_url.format(easting=easting, northing=northing)
resp = requests.get(url, headers=headers)
RenderJSON(resp.json(), height=80)
# Out:
# <div id="ae3e0c21-72df-4c2e-817e-b20b1b8b7b0f" style="height: 80px; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#             renderjson.set_show_to_level(1)
#             document.getElementById('ae3e0c21-72df-4c2e-817e-b20b1b8b7b0f').appendChild(renderjson({"height": "736.4"}))
#         });</script>

# %% [markdown]
# # Profile Service

# %%
import pyproj
import urllib
import json
import requests
coords = [(7.409297165334214,46.88529671006229),
          (7.409638025879345,46.88576455384367),
          (7.408298712384686,46.88758123943866),
          (7.409111955047305,46.88799524126988),
          (7.409137819428239,46.88866089781779),
          (7.409767381399114,46.889092836396266),
          (7.410397090248652,46.889272904119686),
          (7.411944944323117,46.89010085291048),
          (7.41275817238657,46.890676743352145),
          (7.41535614419583,46.89080325685955),
          (7.41666806817831,46.89130726188685),
          (7.417350386721804,46.89130739655902),
          (7.418478787181435,46.891433543998204)]
proj_wgs84 = pyproj.Proj(init='EPSG:4326')
proj_lv95 = pyproj.Proj(init='EPSG:2056')
lv95_coords = []
# x1, y1 = p1(-92.199881,38.56694)
# transform this point to projection 2 coordinates.
# x2, y2 = transform(p1,p2,x1,y1)
for x0, y0 in coords:
    x2, y2 = pyproj.transform(proj_wgs84, proj_lv95, x0, y0)
    lv95_coords.append((x2, y2))
# print(lv95_coords)
base_url = "https://api3.geo.admin.ch/rest/services/profile.json?geom={geom}&sr=2056&nb_points={nb_points}"
# {
#     "type": "Point",
#     "coordinates": [125.6, 10.1]
#   }
geo = {
    "type":"LineString",
    "coordinates":lv95_coords
}
geojson = json.dumps(geo)
urlencgeojson = urllib.parse.quote(geojson)
url = base_url.format(geom=urlencgeojson, nb_points=50)
print('fetching {}'.format(url))
resp = requests.get(url, headers=headers)
if resp.status_code != 200:
    print(repr(resp), resp.text)
result = resp.json()
# print(result)
x = [p['dist'] for p in result]
y = [p['alts']['DTM25'] for p in result]
print("we received {} points".format(len(x)))
# %matplotlib inline

import matplotlib.pyplot as plt
plt.plot(x, y)
plt.title('Hight Profile')
plt.show()
# Out:
# fetching https://api3.geo.admin.ch/rest/services/profile.json?geom=%7B%22type%22%3A%20%22LineString%22%2C%20%22coordinates%22%3A%20%5B%5B2597764.000562072%2C%201192687.0009914723%5D%2C%20%5B2597790.000562082%2C%201192739.0009914935%5D%2C%20%5B2597688.000561937%2C%201192941.0009916169%5D%2C%20%5B2597750.0005619815%2C%201192987.0009916283%5D%2C%20%5B2597752.000561964%2C%201193061.0009916658%5D%2C%20%5B2597800.000561995%2C%201193109.0009916753%5D%2C%20%5B2597848.000562033%2C%201193129.000991674%5D%2C%20%5B2597966.000562116%2C%201193221.0009916872%5D%2C%20%5B2598028.0005621556%2C%201193285.0009917093%5D%2C%20%5B2598226.0005623307%2C%201193299.0009916592%5D%2C%20%5B2598326.0005624066%2C%201193355.0009916648%5D%2C%20%5B2598378.0005624536%2C%201193355.0009916548%5D%2C%20%5B2598464.0005625277%2C%201193369.0009916336%5D%5D%7D&sr=2056&nb_points=50
# we received 51 points

# %%
location = "chaltebruenne"
url = "https://api3.geo.admin.ch/rest/services/api/SearchServer?searchText={location}&type=locations"
resp = requests.get(url.format(location=location), headers=headers)
RenderJSON(resp.json()["results"][0]["attrs"])
# s = requests.Session()
# s.headers.update({'referer': my_referer})
# s.get(url)
# Out:
# <div id="5587f5b4-1fd6-4ccf-bb7e-dacceae86cf9" style="height: 300px; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#             renderjson.set_show_to_level(1)
#             document.getElementById('5587f5b4-1fd6-4ccf-bb7e-dacceae86cf9').appendChild(renderjson({"origin": "gazetteer", "geom_quadindex": "021213110332312302202", "zoomlevel": 10, "lon": 7.410385608673096, "detail": "chaltebruenne koeniz", "rank": 5, "geom_st_box2d": "BOX(597847.109555908 193191.900140605,597847.109555908 193191.900140605)", "lat": 46.88983917236328, "num": 1, "y": 597847.125, "x": 193191.90625, "label": "<i>Ort</i> <b>Chaltebr\u00fcnne</b> (BE) - K\u00f6niz"}))
#         });</script>
